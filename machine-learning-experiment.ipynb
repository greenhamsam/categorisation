# %% [markdown]
# # Sam's awesome Machine Learning experiment
#
# This is my attempt to train a machine learning system to auto-categorise my transactions. Leggo.
#
# ## Problem statement
#
# Use the machine learning workflow to process and transform Sam's personal categorisation data until August 2016 to create a prediction model. This model must predict how I will categorise future transactions with 90% accuracy.
#
# **TODO:** Check what the current accuracy ratio is of 22seven's keyword categorisation system, on my own data, today.

# %% [markdown]
# ## Import things

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Load the csv

# %%
fs_base = '/Users/Sam/Source/categorisation/'
training_url = fs_base + 'categorised-txns-training-set.csv'

df = pd.read_csv(training_url)
df
# Out:
#            id        date                                        description  \
# 0     SBE0001  23/08/2016                         Uber Za Aug20 Vcftj 4* *28
# 1     SBE0002  23/08/2016                                     Uber Bv 4* *28
# 2     SBE0003  22/08/2016                   Epspg_Wechat-Haa5u1h5 _ Rosebank
# 3     SBE0004  21/08/2016                               Ciao Bella Strand Za
# 4     SBE0005  21/08/2016                                   Cafeen Claremont
# 5     SBE0006  20/08/2016                           Wechat Snapscan Rosebank
# 6     SBE0007  19/08/2016                Vineyard Service Stationnewlands Za
# 7     SBE0008  19/08/2016                  St Park Solutions Cashi Cape Town
# 8     SBE0009  18/08/2016                         Uber Za Aug16 Zucne 4* *28
# 9     SBE0010  18/08/2016                                             Mpower
# 10    SBE0011  18/08/2016                         Uber Za Aug16 Bej57 4* *28
# 11    SBE0012  16/08/2016                         19.99 Codecademy Pr 4* *28
# 12    SBE0013  16/08/2016                   Epspg_Wechat-1Qnyuotk _ Rosebank
# 13    SBE0014  15/08/2016                                 Electronic Trf Fee
# 14    SBE0015  15/08/2016                   1Bb Raw Food Hiking Vodsjmxwl34c
# 15    SBE0016  15/08/2016                            Bp Cape Town Greenpoint
# 16    SBE0017  15/08/2016                        Olive Branch Deli Cape Town
# 17    SBE0018  14/08/2016                    Social Bean Caf X3593 Cape Town
# 18    SBE0019  13/08/2016                         Uber Za Aug11 Jccv5 4* *28
# 19    SBE0020  12/08/2016                             Itunes.Com/Bill 4* *28
# 20    SBE0021  12/08/2016                          Lets Go Bowling Claremont
# 21    SBE0022  11/08/2016                               Om Unit Tromut *8530
# 22    SBE0023  10/08/2016                                       You withdrew
# 23    SBE0024  10/08/2016                   Epspg_Wechat-21H2x2ym _ Rosebank
# 24    SBE0025  10/08/2016                         Outdoor Warehouse R 4* *28
# 25    SBE0026  10/08/2016                             La Petite Tarte 4* *28
# 26    SBE0027  10/08/2016                               Wait But Hi *7815 Ca
# 27    SBE0028  09/08/2016                 Checkers Kloof Street Tamboerkloof
# 28    SBE0029  08/08/2016                               Pre-Paid Airtime Fee
# 29    SBE0030  08/08/2016                     1Sa Airtime *5260 Vodsdd8fdt4c
# ...       ...         ...                                                ...
# 1919  SBE1920  23/12/2014                                     Uber Bv Vorden
# 1920  SBE1921  23/12/2014                            Slow Entry Fee Reversal
# 1921  SBE1922  22/12/2014                              C*Eat With Emma *1378
# 1922  SBE1923  22/12/2014                                     Uber Bv Vorden
# 1923  SBE1924  22/12/2014                                     Uber Bv Vorden
# 1924  SBE1925  22/12/2014                                     Uber Bv Vorden
# 1925  SBE1926  21/12/2014                         Amazon.Com Amzn.Com/Billwa
# 1926  SBE1927  21/12/2014                         Amazon.Com Amzn.Com/Billwa
# 1927  SBE1928  21/12/2014                         Amazon.Com Amzn.Com/Billwa
# 1928  SBE1929  20/12/2014                Airtime Topup (Intern Airtime *5260
# 1929  SBE1930  20/12/2014                       Email Sending Fee Kj Bateman
# 1930  SBE1931  20/12/2014                     Smart-Ap Prepaid Airtime *9364
# 1931  SBE1932  20/12/2014                Airtime Topup (Intern Airtime *5260
# 1932  SBE1933  20/12/2014                                Comair Ebuc Gauteng
# 1933  SBE1934  20/12/2014                          Paypal *Steam Games *9001
# 1934  SBE1935  20/12/2014                          Paypal *Steam Games *9001
# 1935  SBE1936  20/12/2014                                Comair Ebuc Gauteng
# 1936  SBE1937  20/12/2014                                Comair Ebuc Gauteng
# 1937  SBE1938  20/12/2014                          Paypal *Steam Games *9001
# 1938  SBE1939  19/12/2014                                       Quirk Salary
# 1939  SBE1940  19/12/2014                                           4 Silcot
# 1940  SBE1941  19/12/2014                     Ongoing Financial Advisory Fee
# 1941  SBE1942  19/12/2014  Ongoing Administration Fee For Psg Wealth Pres...
# 1942  SBE1943  19/12/2014                                     Uber Bv Vorden
# 1943  SBE1944  19/12/2014                                     Uber Bv Vorden
# 1944  SBE1945  19/12/2014                                     Uber Bv Vorden
# 1945  SBE1946  19/12/2014                                     Uber Bv Vorden
# 1946  SBE1947  19/12/2014                                     Uber Bv Vorden
# 1947  SBE1948  19/12/2014                                     Uber Bv Vorden
# 1948  SBE1949  18/12/2014                         C*Oranje Service Cen *1378
#
#                              account    amount  \
# 0                           A Wallet   -170.00
# 1                           A Wallet    -97.00
# 2                    FNB credit card    -25.00
# 3                    FNB credit card   -170.00
# 4                    FNB credit card   -130.00
# 5                    FNB credit card    -30.00
# 6                    FNB credit card   -295.15
# 7                    FNB credit card   -104.00
# 8                           A Wallet    -62.00
# 9                           A Wallet   5000.00
# 10                          A Wallet    -56.00
# 11                          A Wallet   -278.56
# 12                   FNB credit card    -65.00
# 13                   FNB credit card     -7.35
# 14                   FNB credit card   -476.00
# 15                   FNB credit card   -409.24
# 16                   FNB credit card    -95.00
# 17                   FNB credit card   -130.00
# 18                          A Wallet    -24.00
# 19                          A Wallet    -59.99
# 20                   FNB credit card   -100.00
# 21                          A Wallet   1239.87
# 22                    Top 40 Savings  -1239.87
# 23                   FNB credit card    -20.00
# 24                          A Wallet  -5157.00
# 25                          A Wallet   -110.00
# 26                   FNB credit card    -69.17
# 27                   FNB credit card   -287.38
# 28                   FNB credit card     -2.20
# 29                   FNB credit card   -500.00
# ...                              ...       ...
# 1919        FNB Credit Card xxxx8000    -53.49
# 1920        FNB Credit Card xxxx8000      0.00
# 1921                        A Wallet    -80.00
# 1922             FNB Old Credit Card    -85.93
# 1923            FNB Gold Credit Card    -85.93
# 1924        FNB Credit Card xxxx8000    -85.93
# 1925             FNB Old Credit Card   -143.77
# 1926            FNB Gold Credit Card   -143.77
# 1927        FNB Credit Card xxxx8000   -143.77
# 1928                        A Wallet   -399.00
# 1929                        A Wallet      0.00
# 1930                        A Wallet   -299.00
# 1931                        A Wallet  -1000.00
# 1932             FNB Old Credit Card   -581.50
# 1933             FNB Old Credit Card   -315.48
# 1934            FNB Gold Credit Card   -315.48
# 1935            FNB Gold Credit Card   -581.50
# 1936        FNB Credit Card xxxx8000   -581.50
# 1937        FNB Credit Card xxxx8000   -315.48
# 1938                        A Wallet  33888.89
# 1939                        A Wallet -11500.00
# 1940  Z - PSG Short Term Investments     -0.10
# 1941  Z - PSG Short Term Investments     -0.02
# 1942             FNB Old Credit Card    -33.75
# 1943             FNB Old Credit Card    -26.70
# 1944            FNB Gold Credit Card    -26.70
# 1945            FNB Gold Credit Card    -33.75
# 1946        FNB Credit Card xxxx8000    -33.75
# 1947        FNB Credit Card xxxx8000    -26.70
# 1948                        A Wallet   -189.96
#
#                               category
# 0     Public Transport & Taxi Services
# 1     Public Transport & Taxi Services
# 2                Eating Out & Takeouts
# 3                Eating Out & Takeouts
# 4                Eating Out & Takeouts
# 5                               Coffee
# 6                Eating Out & Takeouts
# 7             Tolls, Tickets & Parking
# 8     Public Transport & Taxi Services
# 9                               Income
# 10    Public Transport & Taxi Services
# 11             Tuition and Course Fees
# 12                              Coffee
# 13             Inter-account transfers
# 14    Groceries & Household Essentials
# 15                                Fuel
# 16    Groceries & Household Essentials
# 17               Eating Out & Takeouts
# 18    Public Transport & Taxi Services
# 19                               Gifts
# 20          Concerts, Events & Tickets
# 21             Inter-account transfers
# 22             Inter-account transfers
# 23                              Coffee
# 24         Holidays, Travel, Adventure
# 25               Eating Out & Takeouts
# 26          Concerts, Events & Tickets
# 27    Groceries & Household Essentials
# 28                    Phone & Internet
# 29                    Phone & Internet
# ...                                ...
# 1919  Public Transport & Taxi Services
# 1920           Inter-account transfers
# 1921             Eating Out & Takeouts
# 1922  Public Transport & Taxi Services
# 1923  Public Transport & Taxi Services
# 1924  Public Transport & Taxi Services
# 1925                             Gifts
# 1926                             Gifts
# 1927                             Gifts
# 1928                  Phone & Internet
# 1929           Inter-account transfers
# 1930                  Phone & Internet
# 1931                  Phone & Internet
# 1932       Holidays, Travel, Adventure
# 1933                            Gaming
# 1934                            Gaming
# 1935       Holidays, Travel, Adventure
# 1936       Holidays, Travel, Adventure
# 1937                            Gaming
# 1938                            Income
# 1939                              Rent
# 1940           Bank charges & interest
# 1941           Bank charges & interest
# 1942  Public Transport & Taxi Services
# 1943  Public Transport & Taxi Services
# 1944  Public Transport & Taxi Services
# 1945  Public Transport & Taxi Services
# 1946  Public Transport & Taxi Services
# 1947  Public Transport & Taxi Services
# 1948                              Fuel
#
# [1949 rows x 6 columns]

# %% [markdown]
# ## Check that we're covering rare categories

# %%
num_publictransport = len(df.loc[df['category'] == 'Public Transport & Taxi Services'])
num_gifts = len(df.loc[df['category'] == 'Gifts'])
print('Number of Public Transport & Taxi transactions: {0} ({1:2.2f}%)'.format(num_publictransport, (num_publictransport / len(df)) * 100))
print('Number of Gift transactions: {0} ({1:2.2f}%)'.format(num_gifts, (num_gifts / len(df)) * 100))
# Out:
# Number of Public Transport & Taxi transactions: 243 (12.47%)
# Number of Gift transactions: 56 (2.87%)

# %% [markdown]
# ## INTERLUDE: which algorithm to choose?
#
# What I'm looking for is a supervised, classification algorithm that can handle text.
# Naive Bayes is a place to start but it will treat all fields as equally important.
# Logistic regression is better.
# Decision Trees sound ideal but is super complicated.
# Random Forests :)
# SVM? That sounds like exactly the right thing. Support Vector Machines.
# Essentially I need a neural net?
#
# In summary: start with Naive Bayes, progress to SVM.
#
# This could be a useful thing to read later: http://www.nltk.org/book/

# %% [markdown]
# ## Transform some columns to integers

# %%
account_map = {'A Wallet' : 0, 'FNB credit card' : 1, 'Top 40 Savings' : 2,
       'Old Mutual Global FTSE RAFI® All World Index Feeder Fund (tax free)' : 3,
       'Old Mutual Global FTSE RAFI® All World Index Feeder Fund (not tax free)' : 4,
       'Tax Free Core Diversified Investment' : 5, '22seven Wallet' : 6,
       'FNB Vehicle Loan xxxx7483' : 7, 'Debt I will crush' : 8,
       'Investment with PSG RA' : 9, 'Z - PSG Short Term Investments' : 10,
       'Z - FNB Savings Pocket' : 11, 'Z - Stanlib Short Term' : 12,
       'FNB Old Credit Card' : 13, 'FNB Gold Credit Card' : 14,
       'FNB Credit Card xxxx8000' : 15}

category_map = {'Public Transport & Taxi Services' : 0, 'Eating Out & Takeouts' : 1,
       'Coffee' : 2, 'Tolls, Tickets & Parking' : 3, 'Income' : 4,
       'Tuition and Course Fees' : 5, 'Inter-account transfers' : 6,
       'Groceries & Household Essentials' : 7, 'Fuel' : 8, 'Gifts' : 9,
       'Concerts, Events & Tickets' : 10, 'Holidays, Travel, Adventure' : 11,
       'Phone & Internet' : 12, 'Clothes & Shoes' : 13, 'TV, Music & Streaming' : 14,
       'Investments' : 15, 'Alcohol Cigarettes & Vaping' : 16, 'Interest' : 17,
       'Insurance' : 18, 'Digital Services & Software' : 19, 'Donations to charity' : 20,
       'Domestic Worker & Garden Service' : 21, 'Rent' : 22,
       'Bank charges & interest' : 23, 'Appliances Furniture Decor' : 24,
       'ATM & Cash Transactions' : 25, 'Car Repayments' : 26,
       'Electricity, Water & Rates' : 27, 'Hobbies' : 28, 'Health and Medical Costs' : 29,
       'Things I will be paid back for' : 30, 'Grooming / Cosmetics' : 31, 'Gaming' : 32,
       'Books' : 33, 'Supporting Others' : 34, 'External Consultants / Services' : 35,
       'Savings' : 36, 'Tech' : 37, 'Car Costs' : 38, 'Accessories & Toys' : 39,
       'Sports & Exercise' : 40, 'Taxes' : 41, 'Cape Town Move' : 42,
       'Home Improvement & Maintenance' : 43, 'Refundable work expenses' : 44}

# %%
df.account.unique()
# Out:
# array(['A Wallet', 'FNB credit card', 'Top 40 Savings',
#        'Old Mutual Global FTSE RAFI® All World Index Feeder Fund (tax free)',
#        'Old Mutual Global FTSE RAFI® All World Index Feeder Fund (not tax free)',
#        'Tax Free Core Diversified Investment', '22seven Wallet',
#        'FNB Vehicle Loan xxxx7483', 'Debt I will crush',
#        'Investment with PSG RA', 'Z - PSG Short Term Investments',
#        'Z - FNB Savings Pocket', 'Z - Stanlib Short Term',
#        'FNB Old Credit Card', 'FNB Gold Credit Card',
#        'FNB Credit Card xxxx8000'], dtype=object)

# %%
df.category.unique()
# Out:
# array(['Public Transport & Taxi Services', 'Eating Out & Takeouts',
#        'Coffee', 'Tolls, Tickets & Parking', 'Income',
#        'Tuition and Course Fees', 'Inter-account transfers',
#        'Groceries & Household Essentials', 'Fuel', 'Gifts',
#        'Concerts, Events & Tickets', 'Holidays, Travel, Adventure',
#        'Phone & Internet', 'Clothes & Shoes', 'TV, Music & Streaming',
#        'Investments', 'Alcohol Cigarettes & Vaping', 'Interest',
#        'Insurance', 'Digital Services & Software', 'Donations to charity',
#        'Domestic Worker & Garden Service', 'Rent',
#        'Bank charges & interest', 'Appliances Furniture Decor',
#        'ATM & Cash Transactions', 'Car Repayments',
#        'Electricity, Water & Rates', 'Hobbies', 'Health and Medical Costs',
#        'Things I will be paid back for', 'Grooming / Cosmetics', 'Gaming',
#        'Books', 'Supporting Others', 'External Consultants / Services',
#        'Savings', 'Tech', 'Car Costs', 'Accessories & Toys',
#        'Sports & Exercise', 'Taxes', 'Cape Town Move',
#        'Home Improvement & Maintenance', 'Refundable work expenses'], dtype=object)
